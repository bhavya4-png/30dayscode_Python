# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    binary = bin(n)[2:]          # remove '0b' prefix
    max_consecutive = max(len(group) for group in binary.split('0'))

    print(max_consecutive)
# Out:
# 1
